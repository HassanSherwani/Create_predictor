# %% [markdown]
# # Recurrent Neural Network Model
#
# Applying LSTM

# %% [markdown]
# # 1) importing key modules

# %%
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np 
import pandas as pd
import requests
import pickle

# %%
#For Visuals
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 8
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %%
# for deep learning
from math import sqrt
from sklearn.model_selection import train_test_split
from numpy import concatenate
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from pandas import to_datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2)- Loading data-files

# %%
df = pd.read_csv('testset3.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0        m1        m2        m3        m4        m5        m6  \
# 0           0  0.111771 -0.019099 -0.076978  0.000673 -0.015912  0.123728
# 1           1 -0.184091  0.216673 -0.014954 -0.069772  0.005479  0.353513
#
#          m7        m8        m9    ...          m16       m17       m18  \
# 0 -0.126245  0.004603 -0.011020    ...    -0.140342 -0.129376 -0.006367
# 1 -0.011455  0.051448  0.042422    ...     0.211127 -0.099469 -0.006718
#
#         m19       m20       m21       m22       m23       m24       m25
# 0  0.033683  0.011117  0.161306  0.094439 -0.026443 -0.144413 -0.071164
# 1 -0.096733 -0.051730  0.172214 -0.066792 -0.051919  0.110749  0.077489
#
# [2 rows x 26 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.shape
# Out:
# (80000, 25)

# %% [markdown]
# # 3)- Model Preparation

# %%
# Selecting all columns except last one that is 'm25'.

X = df.iloc[:,:-1].values          
y = df['m25'].values

# %%
X
# Out:
# array([[ 0.11177107, -0.01909882, -0.07697838, ...,  0.09443866,
#         -0.02644323, -0.14441313],
#        [-0.18409085,  0.21667293, -0.01495448, ..., -0.06679168,
#         -0.05191859,  0.11074908],
#        [ 0.00803504,  0.06207178, -0.24195565, ..., -0.06758451,
#         -0.04307759, -0.15583268],
#        ...,
#        [ 0.0934768 , -0.15812533,  0.00374212, ..., -0.07949053,
#          0.14883853,  0.03372341],
#        [-0.04743269, -0.22715774,  0.13080734, ...,  0.18375071,
#          0.13750756,  0.13749909],
#        [ 0.05037231,  0.10659377,  0.10448148, ...,  0.00676053,
#          0.31851738, -0.03230724]])

# %%
X.shape
# Out:
# (80000, 24)

# %%
print(type(X))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ### normalize features

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Split Data to Train and Test

# %%
# As it is neural network so, we tend to use capital letters for train & test sample
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, y, test_size=0.2)

# %%
print(type(X_Train))
print(type(X_Test))
print(type(Y_Train))
print(type(Y_Test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (64000, 24)
# (16000, 24)
# (64000,)
# (16000,)

# %% [markdown]
# ### reshape input

# %%
# reshape input to be 3D [samples, timesteps, features]
X_Train = X_Train.reshape((X_Train.shape[0], 1, X_Train.shape[1]))
X_Test = X_Test.reshape((X_Test.shape[0], 1, X_Test.shape[1]))

# %%
print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (64000, 1, 24)
# (16000, 1, 24)
# (64000,)
# (16000,)

# %% [markdown]
# # 4)-Building Neural Network

# %%
# network architecture
model = Sequential()
model.add(LSTM(50, input_shape=(X_Train.shape[1], X_Train.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 50)                15000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 15,051
# Trainable params: 15,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit model

# %%
history = model.fit(X_Train, Y_Train, epochs=70, batch_size=10, validation_data=(X_Test, Y_Test), verbose=2, shuffle=False)
# Out:
# WARNING:tensorflow:From C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/70
#  - 6s - loss: 0.0238 - val_loss: 0.0234
# Epoch 2/70
#  - 6s - loss: 0.0236 - val_loss: 0.0234
# Epoch 3/70
#  - 6s - loss: 0.0235 - val_loss: 0.0233
# Epoch 4/70
#  - 6s - loss: 0.0235 - val_loss: 0.0233
# Epoch 5/70
#  - 6s - loss: 0.0235 - val_loss: 0.0233
# Epoch 6/70
#  - 6s - loss: 0.0235 - val_loss: 0.0233
# Epoch 7/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 8/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 9/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 10/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 11/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 12/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 13/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 14/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 15/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 16/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 17/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 18/70
#  - 6s - loss: 0.0234 - val_loss: 0.0233
# Epoch 19/70
#  - 6s - loss: 0.0234 - val_loss: 0.0234
# Epoch 20/70
#  - 6s - loss: 0.0234 - val_loss: 0.0234
# Epoch 21/70
#  - 6s - loss: 0.0233 - val_loss: 0.0234
# Epoch 22/70
#  - 6s - loss: 0.0233 - val_loss: 0.0234
# Epoch 23/70
#  - 6s - loss: 0.0233 - val_loss: 0.0234
# Epoch 24/70
#  - 6s - loss: 0.0233 - val_loss: 0.0234
# Epoch 25/70
#  - 6s - loss: 0.0233 - val_loss: 0.0234
# Epoch 26/70
#  - 6s - loss: 0.0233 - val_loss: 0.0235
# Epoch 27/70
#  - 6s - loss: 0.0232 - val_loss: 0.0235
# Epoch 28/70
#  - 6s - loss: 0.0232 - val_loss: 0.0235
# Epoch 29/70
#  - 6s - loss: 0.0232 - val_loss: 0.0235
# Epoch 30/70
#  - 6s - loss: 0.0232 - val_loss: 0.0235
# Epoch 31/70
#  - 6s - loss: 0.0231 - val_loss: 0.0236
# Epoch 32/70
#  - 6s - loss: 0.0231 - val_loss: 0.0236
# Epoch 33/70
#  - 6s - loss: 0.0231 - val_loss: 0.0236
# Epoch 34/70
#  - 6s - loss: 0.0231 - val_loss: 0.0236
# Epoch 35/70
#  - 6s - loss: 0.0230 - val_loss: 0.0237
# Epoch 36/70
#  - 6s - loss: 0.0230 - val_loss: 0.0237
# Epoch 37/70
#  - 6s - loss: 0.0230 - val_loss: 0.0237
# Epoch 38/70
#  - 6s - loss: 0.0230 - val_loss: 0.0237
# Epoch 39/70
#  - 6s - loss: 0.0230 - val_loss: 0.0238
# Epoch 40/70
#  - 6s - loss: 0.0230 - val_loss: 0.0238
# Epoch 41/70
#  - 6s - loss: 0.0229 - val_loss: 0.0238
# Epoch 42/70
#  - 6s - loss: 0.0229 - val_loss: 0.0238
# Epoch 43/70
#  - 6s - loss: 0.0229 - val_loss: 0.0239
# Epoch 44/70
#  - 6s - loss: 0.0229 - val_loss: 0.0239
# Epoch 45/70
#  - 6s - loss: 0.0228 - val_loss: 0.0239
# Epoch 46/70
#  - 6s - loss: 0.0228 - val_loss: 0.0239
# Epoch 47/70
#  - 6s - loss: 0.0228 - val_loss: 0.0240
# Epoch 48/70
#  - 6s - loss: 0.0228 - val_loss: 0.0240
# Epoch 49/70
#  - 6s - loss: 0.0228 - val_loss: 0.0240
# Epoch 50/70
#  - 6s - loss: 0.0227 - val_loss: 0.0240
# Epoch 51/70
#  - 6s - loss: 0.0227 - val_loss: 0.0241
# Epoch 52/70
#  - 6s - loss: 0.0227 - val_loss: 0.0241
# Epoch 53/70
#  - 6s - loss: 0.0227 - val_loss: 0.0241
# Epoch 54/70
#  - 6s - loss: 0.0227 - val_loss: 0.0241
# Epoch 55/70
#  - 6s - loss: 0.0226 - val_loss: 0.0242
# Epoch 56/70
#  - 6s - loss: 0.0226 - val_loss: 0.0242
# Epoch 57/70
#  - 6s - loss: 0.0226 - val_loss: 0.0242
# Epoch 58/70
#  - 6s - loss: 0.0226 - val_loss: 0.0242
# Epoch 59/70
#  - 6s - loss: 0.0226 - val_loss: 0.0242
# Epoch 60/70
#  - 6s - loss: 0.0226 - val_loss: 0.0243
# Epoch 61/70
#  - 6s - loss: 0.0225 - val_loss: 0.0243
# Epoch 62/70
#  - 6s - loss: 0.0225 - val_loss: 0.0243
# Epoch 63/70
#  - 6s - loss: 0.0225 - val_loss: 0.0243
# Epoch 64/70
#  - 6s - loss: 0.0225 - val_loss: 0.0243
# Epoch 65/70
#  - 6s - loss: 0.0225 - val_loss: 0.0243
# Epoch 66/70
#  - 6s - loss: 0.0225 - val_loss: 0.0244
# Epoch 67/70
#  - 6s - loss: 0.0224 - val_loss: 0.0244
# Epoch 68/70
#  - 6s - loss: 0.0224 - val_loss: 0.0244
# Epoch 69/70
#  - 6s - loss: 0.0224 - val_loss: 0.0244
# Epoch 70/70
#  - 6s - loss: 0.0224 - val_loss: 0.0244

# %% [markdown]
# # 5)-Evaluation

# %%
print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (64000, 1, 24)
# (16000, 1, 24)
# (64000,)
# (16000,)

# %%
# make a prediction
yhat = model.predict(X_Test)
# Convert X_Test back to natural state 
X_Test = X_Test.reshape((X_Test.shape[0], X_Test.shape[2]))

# %%
X_Test.shape
# Out:
# (16000, 24)

# %%
yhat[:5]
# Out:
# array([[ 0.01612143],
#        [ 0.03487145],
#        [-0.06433783],
#        [-0.05535317],
#        [-0.01508756]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, X_Test[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
Y_Test = Y_Test.reshape((len(Y_Test), 1))
inv_y = concatenate((Y_Test, X_Test[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error 

mse = mean_squared_error(inv_y, inv_yhat)
mae = mean_absolute_error(inv_y, inv_yhat)
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
r2 = r2_score(inv_y, inv_yhat)

# %%
print('')
print('MSE    : %0.2f ' % mse)
print('MAE    : %0.2f ' % mae)
print('RMSE   : %0.2f ' % rmse)
print('R2     : %0.4f ' % r2)
# Out:
# MSE    : 0.06
# MAE    : 0.19
# RMSE   : 0.24
# R2     : 0.0668

# %% [markdown]
# # 6)-Plot Results

# %%
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.legend()
plt.show()
